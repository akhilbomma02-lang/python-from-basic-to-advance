# %%
a=input()
v=0
c=0

for char in a:
    if char in "AEIOUaeiou":
        v=v+1
    else:
        c=c+1
print(f"vowels are {v} and consonents are {c}")
# Out:
#  Akhil
# vowels are 2 and consonents are 3

# %%
a=input()
for char in a:
    if char.islower():
        print(char.upper(),end="")
    elif char.isupper():
        print(char.lower(),end="")
    else:
        print(char,end="")
# Out:
#  Akhil
# aKHIL
